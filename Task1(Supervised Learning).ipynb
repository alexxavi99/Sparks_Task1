# %% [markdown]
# **THE SPARKS FOUNDATION  MAY-2021**
#
# Task 1 : PREDICTION USING SUPERVISED LEARNING
#
# Problem : Predicting the percentage of student based on the number of study hours.
#
# Done by : Arockia Alex Xavier Raj J

# %% [markdown]
# Importing the Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="darkgrid")
import sklearn

# %% [markdown]
# Importing the Dataset

# %%
data=pd.read_csv("https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv")
print(data.head())
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# Plotting the Distribution using Scatterplot

# %%
sns.scatterplot(data=data,x='Hours',y='Scores')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Relationship between Hours & Scores")
# Out:
# Text(0.5, 1.0, 'Relationship between Hours & Scores')

# %% [markdown]
# Data Preparation

# %%
#Dividing the data into inputs and outputs
x= data[['Hours']].values
y= data['Scores'].values

# %% [markdown]
# Model Selection

# %%
#Selecting the Model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

#Fitting the Model
model.fit(X_train,Y_train)

#Viewing how the model is fitted using Regression plot
sns.regplot(X_train,Y_train)
plt.xlabel("Hours")
plt.ylabel("Scores")
plt.title("Hours vs Scores")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Hours vs Scores')

# %% [markdown]
#  Splitting the data into training and test sets

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=0)
print("Training Successful")

# %% [markdown]
# Calculating R Square

# %%
#R_Squared value
print(model.score(X_test,Y_test))
# Out:
# 0.9454906892105354

# %% [markdown]
# Making Predictions

# %%
#Testing data
print(X_test)
y_pred = model.predict(X_test)
#Predicted Data
print(y_pred)
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]
# array([16.88414476, 33.73226078, 75.357018  , 26.79480124, 60.49103328])

# %% [markdown]
# Comparing Actual vs Predicted Values

# %%
pred = pd.DataFrame({'Actual':Y_test,'Predicted':y_pred})
print(pred)
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %% [markdown]
# Predicting score if a student studies for 9.25 hrs/ day

# %%
#Finding the student's score if the hour is 9.25.
hours = 9.25 
pred1 = model.predict([[hours]])

result=pd.DataFrame({"Hours":hours,"Predicted Score":pred1})

print(result)
# Out:
#    Hours  Predicted Score
# 0   9.25        93.691732

# %% [markdown]
# Model Evaluation

# %%
from sklearn import metrics  
#Finding the Mean Absolute Error
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(Y_test, y_pred))
# Out:
# Mean Absolute Error: 4.183859899002982
